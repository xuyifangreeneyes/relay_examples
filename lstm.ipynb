# %%
from tvm import relay
from tvm.relay.prelude import Prelude
from tvm.relay.testing import layers, create_workload

# %%
def lstm_cell(num_hidden, batch_size=1, dtype="float32", name=""):
    builder = relay.ScopeBuilder()
    
    input_type = relay.TensorType((batch_size, num_hidden), dtype)
    weight_type = relay.TensorType((4*num_hidden, num_hidden), dtype)
    bias_type = relay.TensorType((4*num_hidden,), dtype)
    
    dense_type = relay.TensorType((batch_size, 4*num_hidden), dtype)
    slice_type = relay.TupleType([input_type, input_type,
                                  input_type, input_type])
    ret_type = relay.TupleType([input_type,
                                relay.TupleType([input_type, input_type])])
    
    inputs = relay.Var("inputs", input_type)
    states = relay.Var("states", 
                       relay.TupleType([input_type, input_type]))
    
    i2h_weight = relay.Var("i2h_weight", weight_type)
    i2h_bias = relay.Var("i2h_bias", bias_type)
    
    h2h_weight = relay.Var("h2h_weight", weight_type)
    h2h_bias = relay.Var("h2h_bias", bias_type)
    
    i2h = builder.let(("i2h", dense_type),
                      layers.dense_add_bias(
                          data=inputs,
                          units=num_hidden * 4,
                          weight=i2h_weight, bias=i2h_bias,
                          name="%si2h" % name))
    h2h = builder.let(("h2h", dense_type),
                      layers.dense_add_bias(
                          data=relay.TupleGetItem(states, 0),
                          units=num_hidden * 4,
                          name="%sh2h" % name))
    gates = builder.let(("gates", dense_type), relay.add(i2h, h2h))
    slice_gates = builder.let(("slice_gates", slice_type),
                              relay.split(gates,
                                          indices_or_sections=4,
                                          axis=1).astuple())
    
    in_gate = builder.let(("in_gate", input_type),
                          relay.sigmoid(relay.TupleGetItem(slice_gates, 0)))
    forget_gate = builder.let(("forget_gate", input_type),
                              relay.sigmoid(relay.TupleGetItem(slice_gates, 1)))
    in_transform = builder.let(("in_transform", input_type),
                               relay.tanh(relay.TupleGetItem(slice_gates, 2)))
    out_gate = builder.let(("out_gate", input_type),
                           relay.sigmoid(relay.TupleGetItem(slice_gates, 3)))
    
    next_c = builder.let(("next_c", input_type),
                         relay.add(relay.multiply(forget_gate,
                                                  relay.TupleGetItem(states, 1)),
                                   relay.multiply(in_gate, in_transform)))
    next_h = builder.let(("next_h", input_type),
                         relay.multiply(out_gate, relay.tanh(next_c)))
    ret = builder.let(("ret", ret_type),
                      relay.Tuple([next_h, relay.Tuple([next_h, next_c])]))
    builder.ret(ret)

    body = builder.get()

    return relay.Function([inputs, states, i2h_weight,
                           i2h_bias, h2h_weight, h2h_bias],
                          body, ret_type)

# %%
def get_types(num_hidden, batch_size, dtype):
    input_type = relay.TensorType((batch_size, num_hidden), dtype)
    weight_type = relay.TensorType((4*num_hidden, num_hidden), dtype)
    bias_type = relay.TensorType((4*num_hidden,), dtype)
    state_type = relay.TupleType([input_type, input_type])
    cell_type = relay.TupleType([input_type, state_type])
    return input_type, weight_type, bias_type, state_type, cell_type

# %%
def unroll_lstm(iterations, num_hidden, batch_size=1, dtype="float32"):
    input_type, weight_type, bias_type, state_type, cell_type = get_types(num_hidden, batch_size, dtype)
    
    builder = relay.ScopeBuilder()

    zeros = builder.let(("zeros", input_type),
                        relay.zeros((batch_size, num_hidden), dtype))
    init_states = builder.let(("init_states", state_type),
                              relay.Tuple([zeros, zeros]))

    states = init_states
    out = None

    for i in range(iterations):
        inputs = relay.Var("data", input_type)
        i2h_weight = relay.Var("i2h_%s_weight" % i, weight_type)
        i2h_bias = relay.Var("i2h_%i_bias" % i, bias_type)
        h2h_weight = relay.Var("h2h_%s_weight" % i, weight_type)
        h2h_bias = relay.Var("h2h_%s_bias" % i, bias_type)

        cell_fn = lstm_cell(num_hidden, batch_size, dtype, "lstm_%s" % i)

        call = builder.let(("call_%s" % i, cell_type),
                           relay.Call(cell_fn,
                                      [inputs, states, i2h_weight,
                                       i2h_bias, h2h_weight, h2h_bias]))
        new_out = builder.let(("out_%s" % i, input_type),
                              relay.TupleGetItem(call, 0))
        new_states = builder.let(("states_%s" % i, state_type),
                                 relay.TupleGetItem(call, 1))
        states = new_states
        out = new_out

    builder.ret(out)
    body = builder.get()
    args = relay.analysis.free_vars(body)
    return relay.Function(args, body, input_type)

# %%
mod = relay.Module()
p = Prelude(mod)
l = p.l
nil = p.nil
cons = p.cons
hd = p.hd
tl = p.tl
nth = p.nth
# x = relay.Var('x', l(relay.TensorType(shape=(), dtype='float32')))
# print(x)

# %%
def get_cell_builder(num_hidden, batch_size, dtype, args, states=None, previous_list=None, lstm_rec=None):
    input_type, weight_type, bias_type, state_type, cell_type = get_types(num_hidden, batch_size, dtype)
    cell_fn = lstm_cell(num_hidden, batch_size, dtype, "lstm_cell")
    builder = relay.ScopeBuilder()
    if states == None:
        assert(previous_list != None and lstm_rec != None)
        previous_res = builder.let(("previous_res", cell_type), lstm_rec(previous_list))
        states = builder.let(("states", state_type), relay.TupleGetItem(previous_res, 1))
    inputs = builder.let(("data", input_type), relay.TupleGetItem(args, 0))
    i2h_weight = builder.let(("i2h_weight", weight_type), relay.TupleGetItem(args, 1))
    i2h_bias = builder.let(("i2h_bias", bias_type), relay.TupleGetItem(args, 2))
    h2h_weight = builder.let(("h2h_weight", weight_type), relay.TupleGetItem(args, 3))
    h2h_bias = builder.let(("h2h_bias", bias_type), relay.TupleGetItem(args, 4))
    res = builder.let(("res", cell_type), 
                      relay.Call(cell_fn, [inputs, states, i2h_weight, i2h_bias, h2h_weight, h2h_bias]))
    builder.ret(res)
    return builder

# %%
def recursive_lstm(iterations, num_hidden, batch_size=1, dtype="float32"):
    input_type, weight_type, bias_type, state_type, cell_type = get_types(num_hidden, batch_size, dtype)
    args_type = relay.TupleType([input_type, weight_type, bias_type, weight_type, bias_type])
    
#     args_type = relay.TensorType((2, 2), "float32")
    
    args_list = nil()
    for i in range(iterations):
        inputs = relay.Var("data", input_type)
        i2h_weight = relay.Var("i2h_%s_weight" % i, weight_type)
        i2h_bias = relay.Var("i2h_%i_bias" % i, bias_type)
        h2h_weight = relay.Var("h2h_%s_weight" % i, weight_type)
        h2h_bias = relay.Var("h2h_%s_bias" % i, bias_type)
        args = relay.Tuple([inputs, i2h_weight, i2h_bias, h2h_weight, h2h_bias])
        args_list = cons(args, args_list)

#     for i in range(iterations):
#         args = relay.Var("data", args_type)
#         args_list = cons(args, args_list)
    
    builder = relay.scope_builder.ScopeBuilder()
    
    lstm_rec = relay.Var("lstm_rec")
    
    zeros = builder.let(("zeros", input_type), relay.zeros((batch_size, num_hidden), dtype))
    init_states = builder.let(("init_states", state_type), relay.Tuple([zeros, zeros]))
    first_args = relay.Var("first_args", args_type)
    first_br = get_cell_builder(num_hidden, batch_size, dtype, first_args, states=init_states)
    
    previous_list = relay.Var("previous_list", l(args_type))
    current_args = relay.Var("current_args", args_type)
    current_br = get_cell_builder(num_hidden, batch_size, dtype, current_args, 
                                  previous_list=previous_list, lstm_rec=lstm_rec)
    
    current_list = relay.Var("current_list", l(args_type))
    match = builder.let(("match", cell_type), 
        relay.Match(
            current_list,
            [relay.Clause(relay.PatternConstructor(cons, 
                                                   [relay.PatternVar(first_args), relay.PatternConstructor(nil)]), 
                          first_br.get()
                         ),
             relay.Clause(relay.PatternConstructor(cons, 
                                                   [relay.PatternVar(current_args), relay.PatternVar(previous_list)]), 
                          current_br.get()
                         )
            ],
            complete=False))
    
#     current_list = relay.Var("current_list", l(args_type))
#     match = builder.let(("match", relay.TensorType((), "int32")), 
#         relay.Match(
#             current_list,
#             [relay.Clause(relay.PatternConstructor(cons, 
#                                                    [relay.PatternVar(first_args), relay.PatternConstructor(nil)]), 
#                           relay.const(1, dtype="int32")
#                          ),
#              relay.Clause(relay.PatternConstructor(cons, 
#                                                    [relay.PatternVar(current_args), relay.PatternVar(previous_list)]), 
#                           relay.const(1, dtype="int32") + lstm_rec(previous_list)
#                          )
#             ],
#             complete=False))

    builder.ret(match)
    func = relay.Function([current_list], builder.get())
    ret = relay.Let(lstm_rec, func, lstm_rec(args_list))
    out = relay.TupleGetItem(ret, 0)
    args = relay.analysis.free_vars(out)
    
#     builder.ret(match)
#     func = relay.Function([current_list], builder.get())
#     ret = relay.Let(lstm_rec, func, lstm_rec(args_list))
#     args = relay.analysis.free_vars(ret)

    return relay.Function(args, out)

# %%
# ll = mod.get_global_type_var("List")
# print(ll)
# print(mod.get_global_type_vars())
mod["main"] = recursive_lstm(2, 2)
print(mod["main"])
mod = relay.transform.InferType()(mod)
print(mod["main"].params)
# Out:
# v0.0.4
# fn (%lstm_cellh2h_weight: Tensor[(8, 2), float32], %lstm_cellh2h_bias: Tensor[(8), float32], %lstm_cellh2h_weight1: Tensor[(8, 2), float32], %lstm_cellh2h_bias1: Tensor[(8), float32], %data: Tensor[(1, 2), float32], %i2h_1_weight: Tensor[(8, 2), float32], %i2h_1_bias: Tensor[(8), float32], %h2h_1_weight: Tensor[(8, 2), float32], %h2h_1_bias: Tensor[(8), float32], %data1: Tensor[(1, 2), float32], %i2h_0_weight: Tensor[(8, 2), float32], %i2h_0_bias: Tensor[(8), float32], %h2h_0_weight: Tensor[(8, 2), float32], %h2h_0_bias: Tensor[(8), float32]) -> Tensor[(1, 2), float32] {
#   %31 = (
#     let %lstm_rec-malformed-ir = fn (%current_list: List[(Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32])]) -> (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) {
#       let %zeros: Tensor[(1, 2), float32] = zeros(shape=[1, 2], dtype="float32") /* ty=Tensor[(1, 2), float32] */;
#       let %init_states: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = (%zeros, %zeros);
#       let %match: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = match? (%current_list) {
#         Cons(%first_args: (Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32]), Nil) => {
#           let %data2: Tensor[(1, 2), float32] = %first_args.0;
#           let %i2h_weight: Tensor[(8, 2), float32] = %first_args.1;
#           let %i2h_bias: Tensor[(8), float32] = %first_args.2;
#           let %h2h_weight: Tensor[(8, 2), float32] = %first_args.3;
#           let %h2h_bias: Tensor[(8), float32] = %first_args.4;
#           %12 = fn (%inputs: Tensor[(1, 2), float32], %states: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]), %i2h_weight1: Tensor[(8, 2), float32], %i2h_bias1: Tensor[(8), float32], %h2h_weight1: Tensor[(8, 2), float32], %h2h_bias1: Tensor[(8), float32]) -> (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) {
#             %0 = nn.dense(%inputs, %i2h_weight1, units=8) /* ty=Tensor[(1, 8), float32] */;
#             let %i2h: Tensor[(1, 8), float32] = nn.bias_add(%0, %i2h_bias1, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#             %1 = %states.0;
#             %2 = nn.dense(%1, %lstm_cellh2h_weight, units=8) /* ty=Tensor[(1, 8), float32] */;
#             let %h2h: Tensor[(1, 8), float32] = nn.bias_add(%2, %lstm_cellh2h_bias, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#             let %gates: Tensor[(1, 8), float32] = add(%i2h, %h2h) /* ty=Tensor[(1, 8), float32] */;
#             let %slice_gates: (Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = split(%gates, indices_or_sections=4, axis=1) /* ty=(Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) */;
#             %3 = %slice_gates.0;
#             let %in_gate: Tensor[(1, 2), float32] = sigmoid(%3) /* ty=Tensor[(1, 2), float32] */;
#             %4 = %slice_gates.1;
#             let %forget_gate: Tensor[(1, 2), float32] = sigmoid(%4) /* ty=Tensor[(1, 2), float32] */;
#             %5 = %slice_gates.2;
#             let %in_transform: Tensor[(1, 2), float32] = tanh(%5) /* ty=Tensor[(1, 2), float32] */;
#             %6 = %slice_gates.3;
#             let %out_gate: Tensor[(1, 2), float32] = sigmoid(%6) /* ty=Tensor[(1, 2), float32] */;
#             %7 = %states.1;
#             %8 = multiply(%forget_gate, %7) /* ty=Tensor[(1, 2), float32] */;
#             %9 = multiply(%in_gate, %in_transform) /* ty=Tensor[(1, 2), float32] */;
#             let %next_c: Tensor[(1, 2), float32] = add(%8, %9) /* ty=Tensor[(1, 2), float32] */;
#             %10 = tanh(%next_c) /* ty=Tensor[(1, 2), float32] */;
#             let %next_h: Tensor[(1, 2), float32] = multiply(%out_gate, %10) /* ty=Tensor[(1, 2), float32] */;
#             %11 = (%next_h, %next_c);
#             let %ret: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = (%next_h, %11);
#             %ret
#           };
#           let %res: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = %12(%data2, %init_states, %i2h_weight, %i2h_bias, %h2h_weight, %h2h_bias) /* ty=(Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) */;
#           %res
#         },
#         Cons(%current_args: (Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32]), %previous_list: List[(Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32])]) => {
#           free_var %lstm_rec: fn (List[(Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32])]) -> (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32]))
#           let %previous_res: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = %lstm_rec(%previous_list) /* ty=(Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) */;
#           let %states1: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = %previous_res.1;
#           let %data3: Tensor[(1, 2), float32] = %current_args.0;
#           let %i2h_weight2: Tensor[(8, 2), float32] = %current_args.1;
#           let %i2h_bias2: Tensor[(8), float32] = %current_args.2;
#           let %h2h_weight2: Tensor[(8, 2), float32] = %current_args.3;
#           let %h2h_bias2: Tensor[(8), float32] = %current_args.4;
#           %25 = fn (%inputs1: Tensor[(1, 2), float32], %states2: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]), %i2h_weight3: Tensor[(8, 2), float32], %i2h_bias3: Tensor[(8), float32], %h2h_weight3: Tensor[(8, 2), float32], %h2h_bias3: Tensor[(8), float32]) -> (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) {
#             %13 = nn.dense(%inputs1, %i2h_weight3, units=8) /* ty=Tensor[(1, 8), float32] */;
#             let %i2h1: Tensor[(1, 8), float32] = nn.bias_add(%13, %i2h_bias3, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#             %14 = %states2.0;
#             %15 = nn.dense(%14, %lstm_cellh2h_weight1, units=8) /* ty=Tensor[(1, 8), float32] */;
#             let %h2h1: Tensor[(1, 8), float32] = nn.bias_add(%15, %lstm_cellh2h_bias1, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#             let %gates1: Tensor[(1, 8), float32] = add(%i2h1, %h2h1) /* ty=Tensor[(1, 8), float32] */;
#             let %slice_gates1: (Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = split(%gates1, indices_or_sections=4, axis=1) /* ty=(Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) */;
#             %16 = %slice_gates1.0;
#             let %in_gate1: Tensor[(1, 2), float32] = sigmoid(%16) /* ty=Tensor[(1, 2), float32] */;
#             %17 = %slice_gates1.1;
#             let %forget_gate1: Tensor[(1, 2), float32] = sigmoid(%17) /* ty=Tensor[(1, 2), float32] */;
#             %18 = %slice_gates1.2;
#             let %in_transform1: Tensor[(1, 2), float32] = tanh(%18) /* ty=Tensor[(1, 2), float32] */;
#             %19 = %slice_gates1.3;
#             let %out_gate1: Tensor[(1, 2), float32] = sigmoid(%19) /* ty=Tensor[(1, 2), float32] */;
#             %20 = %states2.1;
#             %21 = multiply(%forget_gate1, %20) /* ty=Tensor[(1, 2), float32] */;
#             %22 = multiply(%in_gate1, %in_transform1) /* ty=Tensor[(1, 2), float32] */;
#             let %next_c1: Tensor[(1, 2), float32] = add(%21, %22) /* ty=Tensor[(1, 2), float32] */;
#             %23 = tanh(%next_c1) /* ty=Tensor[(1, 2), float32] */;
#             let %next_h1: Tensor[(1, 2), float32] = multiply(%out_gate1, %23) /* ty=Tensor[(1, 2), float32] */;
#             %24 = (%next_h1, %next_c1);
#             let %ret1: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = (%next_h1, %24);
#             %ret1
#           };
#           let %res1: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = %25(%data3, %states1, %i2h_weight2, %i2h_bias2, %h2h_weight2, %h2h_bias2) /* ty=(Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) */;
#           %res1
#         },
#       };
#       %match
#     };
#     %26 = (%data, %i2h_1_weight, %i2h_1_bias, %h2h_1_weight, %h2h_1_bias);
#     %27 = (%data1, %i2h_0_weight, %i2h_0_bias, %h2h_0_weight, %h2h_0_bias);
#     %28 = Nil /* ty=List[(Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32])] */;
#     %29 = Cons(%27, %28) /* ty=List[(Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32])] */;
#     %30 = Cons(%26, %29) /* ty=List[(Tensor[(1, 2), float32], Tensor[(8, 2), float32], Tensor[(8), float32], Tensor[(8, 2), float32], Tensor[(8), float32])] */;
#     %lstm_rec(%30) /* ty=(Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) */
#   );
#   %31.0
# }
# [Var(lstm_cellh2h_weight, ty=TensorType([8, 2], float32)), Var(lstm_cellh2h_bias, ty=TensorType([8], float32)), Var(lstm_cellh2h_weight, ty=TensorType([8, 2], float32)), Var(lstm_cellh2h_bias, ty=TensorType([8], float32)), Var(data, ty=TensorType([1, 2], float32)), Var(i2h_1_weight, ty=TensorType([8, 2], float32)), Var(i2h_1_bias, ty=TensorType([8], float32)), Var(h2h_1_weight, ty=TensorType([8, 2], float32)), Var(h2h_1_bias, ty=TensorType([8], float32)), Var(data, ty=TensorType([1, 2], float32)), Var(i2h_0_weight, ty=TensorType([8, 2], float32)), Var(i2h_0_bias, ty=TensorType([8], float32)), Var(h2h_0_weight, ty=TensorType([8, 2], float32)), Var(h2h_0_bias, ty=TensorType([8], float32))]

# %%
def get_workload(iterations, num_hidden, batch_size=1, dtype="float32"):
    net =  unroll_lstm(iterations, num_hidden, batch_size, dtype)
    return create_workload(net)

# %%
iterations = 2
num_hidden = 2
net, params = get_workload(iterations, num_hidden)

# %%
print(net)
print(net["main"].params)
print(params)
# Out:
# v0.0.4
# def @main(%lstm_0h2h_weight: Tensor[(8, 2), float32], %lstm_0h2h_bias: Tensor[(8), float32], %data: Tensor[(1, 2), float32], %i2h_0_weight: Tensor[(8, 2), float32], %i2h_0_bias: Tensor[(8), float32], %h2h_0_weight: Tensor[(8, 2), float32], %h2h_0_bias: Tensor[(8), float32], %lstm_1h2h_weight: Tensor[(8, 2), float32], %lstm_1h2h_bias: Tensor[(8), float32], %data1: Tensor[(1, 2), float32], %i2h_1_weight: Tensor[(8, 2), float32], %i2h_1_bias: Tensor[(8), float32], %h2h_1_weight: Tensor[(8, 2), float32], %h2h_1_bias: Tensor[(8), float32]) -> Tensor[(1, 2), float32] {
#   let %zeros: Tensor[(1, 2), float32] = zeros(shape=[1, 2], dtype="float32") /* ty=Tensor[(1, 2), float32] */;
#   let %init_states: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = (%zeros, %zeros);
#   %12 = fn (%inputs: Tensor[(1, 2), float32], %states: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]), %i2h_weight: Tensor[(8, 2), float32], %i2h_bias: Tensor[(8), float32], %h2h_weight: Tensor[(8, 2), float32], %h2h_bias: Tensor[(8), float32]) -> (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) {
#     %0 = nn.dense(%inputs, %i2h_weight, units=8) /* ty=Tensor[(1, 8), float32] */;
#     let %i2h: Tensor[(1, 8), float32] = nn.bias_add(%0, %i2h_bias, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#     %1 = %states.0;
#     %2 = nn.dense(%1, %lstm_0h2h_weight, units=8) /* ty=Tensor[(1, 8), float32] */;
#     let %h2h: Tensor[(1, 8), float32] = nn.bias_add(%2, %lstm_0h2h_bias, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#     let %gates: Tensor[(1, 8), float32] = add(%i2h, %h2h) /* ty=Tensor[(1, 8), float32] */;
#     let %slice_gates: (Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = split(%gates, indices_or_sections=4, axis=1) /* ty=(Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) */;
#     %3 = %slice_gates.0;
#     let %in_gate: Tensor[(1, 2), float32] = sigmoid(%3) /* ty=Tensor[(1, 2), float32] */;
#     %4 = %slice_gates.1;
#     let %forget_gate: Tensor[(1, 2), float32] = sigmoid(%4) /* ty=Tensor[(1, 2), float32] */;
#     %5 = %slice_gates.2;
#     let %in_transform: Tensor[(1, 2), float32] = tanh(%5) /* ty=Tensor[(1, 2), float32] */;
#     %6 = %slice_gates.3;
#     let %out_gate: Tensor[(1, 2), float32] = sigmoid(%6) /* ty=Tensor[(1, 2), float32] */;
#     %7 = %states.1;
#     %8 = multiply(%forget_gate, %7) /* ty=Tensor[(1, 2), float32] */;
#     %9 = multiply(%in_gate, %in_transform) /* ty=Tensor[(1, 2), float32] */;
#     let %next_c: Tensor[(1, 2), float32] = add(%8, %9) /* ty=Tensor[(1, 2), float32] */;
#     %10 = tanh(%next_c) /* ty=Tensor[(1, 2), float32] */;
#     let %next_h: Tensor[(1, 2), float32] = multiply(%out_gate, %10) /* ty=Tensor[(1, 2), float32] */;
#     %11 = (%next_h, %next_c);
#     let %ret: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = (%next_h, %11);
#     %ret
#   };
#   let %call_0: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = %12(%data, %init_states, %i2h_0_weight, %i2h_0_bias, %h2h_0_weight, %h2h_0_bias) /* ty=(Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) */;
#   let %out_0: Tensor[(1, 2), float32] = %call_0.0;
#   let %states_0: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = %call_0.1;
#   %25 = fn (%inputs1: Tensor[(1, 2), float32], %states1: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]), %i2h_weight1: Tensor[(8, 2), float32], %i2h_bias1: Tensor[(8), float32], %h2h_weight1: Tensor[(8, 2), float32], %h2h_bias1: Tensor[(8), float32]) -> (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) {
#     %13 = nn.dense(%inputs1, %i2h_weight1, units=8) /* ty=Tensor[(1, 8), float32] */;
#     let %i2h1: Tensor[(1, 8), float32] = nn.bias_add(%13, %i2h_bias1, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#     %14 = %states1.0;
#     %15 = nn.dense(%14, %lstm_1h2h_weight, units=8) /* ty=Tensor[(1, 8), float32] */;
#     let %h2h1: Tensor[(1, 8), float32] = nn.bias_add(%15, %lstm_1h2h_bias, axis=-1) /* ty=Tensor[(1, 8), float32] */;
#     let %gates1: Tensor[(1, 8), float32] = add(%i2h1, %h2h1) /* ty=Tensor[(1, 8), float32] */;
#     let %slice_gates1: (Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = split(%gates1, indices_or_sections=4, axis=1) /* ty=(Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32], Tensor[(1, 2), float32]) */;
#     %16 = %slice_gates1.0;
#     let %in_gate1: Tensor[(1, 2), float32] = sigmoid(%16) /* ty=Tensor[(1, 2), float32] */;
#     %17 = %slice_gates1.1;
#     let %forget_gate1: Tensor[(1, 2), float32] = sigmoid(%17) /* ty=Tensor[(1, 2), float32] */;
#     %18 = %slice_gates1.2;
#     let %in_transform1: Tensor[(1, 2), float32] = tanh(%18) /* ty=Tensor[(1, 2), float32] */;
#     %19 = %slice_gates1.3;
#     let %out_gate1: Tensor[(1, 2), float32] = sigmoid(%19) /* ty=Tensor[(1, 2), float32] */;
#     %20 = %states1.1;
#     %21 = multiply(%forget_gate1, %20) /* ty=Tensor[(1, 2), float32] */;
#     %22 = multiply(%in_gate1, %in_transform1) /* ty=Tensor[(1, 2), float32] */;
#     let %next_c1: Tensor[(1, 2), float32] = add(%21, %22) /* ty=Tensor[(1, 2), float32] */;
#     %23 = tanh(%next_c1) /* ty=Tensor[(1, 2), float32] */;
#     let %next_h1: Tensor[(1, 2), float32] = multiply(%out_gate1, %23) /* ty=Tensor[(1, 2), float32] */;
#     %24 = (%next_h1, %next_c1);
#     let %ret1: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = (%next_h1, %24);
#     %ret1
#   };
#   let %call_1: (Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) = %25(%data1, %states_0, %i2h_1_weight, %i2h_1_bias, %h2h_1_weight, %h2h_1_bias) /* ty=(Tensor[(1, 2), float32], (Tensor[(1, 2), float32], Tensor[(1, 2), float32])) */;
#   let %out_1: Tensor[(1, 2), float32] = %call_1.0;
#   let %states_1: (Tensor[(1, 2), float32], Tensor[(1, 2), float32]) = %call_1.1;
#   %out_1
# }
#
# [Var(lstm_0h2h_weight, ty=TensorType([8, 2], float32)), Var(lstm_0h2h_bias, ty=TensorType([8], float32)), Var(data, ty=TensorType([1, 2], float32)), Var(i2h_0_weight, ty=TensorType([8, 2], float32)), Var(i2h_0_bias, ty=TensorType([8], float32)), Var(h2h_0_weight, ty=TensorType([8, 2], float32)), Var(h2h_0_bias, ty=TensorType([8], float32)), Var(lstm_1h2h_weight, ty=TensorType([8, 2], float32)), Var(lstm_1h2h_bias, ty=TensorType([8], float32)), Var(data, ty=TensorType([1, 2], float32)), Var(i2h_1_weight, ty=TensorType([8, 2], float32)), Var(i2h_1_bias, ty=TensorType([8], float32)), Var(h2h_1_weight, ty=TensorType([8, 2], float32)), Var(h2h_1_bias, ty=TensorType([8], float32))]
# {'lstm_0h2h_weight': <tvm.NDArray shape=(8, 2), cpu(0)>
# array([[ 0.07562155,  0.33336994],
#        [ 0.15920034,  0.06953273],
#        [-0.11827347,  0.22601819],
#        [-0.09668948,  0.6069321 ],
#        [ 0.71830326, -0.18057162],
#        [ 0.45193848,  0.04476382],
#        [ 0.10541418,  0.6593315 ],
#        [-0.6645481 , -0.63961655]], dtype=float32), 'lstm_0h2h_bias': <tvm.NDArray shape=(8,), cpu(0)>
# array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32), 'i2h_0_weight': <tvm.NDArray shape=(8, 2), cpu(0)>
# array([[-0.74327445,  0.51529247],
#        [ 0.43091857,  0.5732204 ],
#        [ 0.74147236,  0.46345446],
#        [-0.05967592,  0.43459395],
#        [-0.5913667 ,  0.21676472],
#        [-0.55251473,  0.6888781 ],
#        [ 0.03384728, -0.13220516],
#        [-0.36474887,  0.42484102]], dtype=float32), 'i2h_0_bias': <tvm.NDArray shape=(8,), cpu(0)>
# array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32), 'h2h_0_weight': <tvm.NDArray shape=(8, 2), cpu(0)>
# array([[-0.06793161,  0.10601742],
#        [-0.74548763,  0.18224013],
#        [ 0.17365795,  0.18115337],
#        [ 0.68745154,  0.2816748 ],
#        [-0.21764943, -0.09754968],
#        [ 0.30616894, -0.68129575],
#        [ 0.2583539 ,  0.26435104],
#        [-0.4486734 , -0.5748649 ]], dtype=float32), 'h2h_0_bias': <tvm.NDArray shape=(8,), cpu(0)>
# array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32), 'lstm_1h2h_weight': <tvm.NDArray shape=(8, 2), cpu(0)>
# array([[-0.28593716, -0.21113837],
#        [ 0.10874837, -0.09511813],
#        [ 0.7565855 , -0.61650956],
#        [-0.4510062 , -0.52469707],
#        [ 0.2371944 , -0.38219902],
#        [-0.05219113, -0.39593416],
#        [-0.52832204, -0.60360426],
#        [ 0.24218476, -0.5605246 ]], dtype=float32), 'lstm_1h2h_bias': <tvm.NDArray shape=(8,), cpu(0)>
# array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32), 'i2h_1_weight': <tvm.NDArray shape=(8, 2), cpu(0)>
# array([[-0.47005257, -0.2033701 ],
#        [ 0.49728057, -0.62416804],
#        [ 0.523542  , -0.62572163],
#        [ 0.7381278 , -0.04856535],
#        [ 0.7385951 ,  0.16242598],
#        [ 0.37066555, -0.7138872 ],
#        [-0.336474  , -0.588389  ],
#        [-0.31581825, -0.5906645 ]], dtype=float32), 'i2h_1_bias': <tvm.NDArray shape=(8,), cpu(0)>
# array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32), 'h2h_1_weight': <tvm.NDArray shape=(8, 2), cpu(0)>
# array([[-0.28197923, -0.1328232 ],
#        [-0.6752198 ,  0.29817653],
#        [ 0.10317853, -0.36345702],
#        [ 0.03601573, -0.6290647 ],
#        [ 0.11765581,  0.6650628 ],
#        [-0.28107178,  0.25935104],
#        [-0.5704163 ,  0.33513266],
#        [-0.32625067, -0.49079782]], dtype=float32), 'h2h_1_bias': <tvm.NDArray shape=(8,), cpu(0)>
# array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32)}

# %%
print(net)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f07152f7252b> in <module>()
# ----> 1 print(net)
#
# NameError: name 'net' is not defined

# %%
a = 1
b = 2
assert(a == None and b != None)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-8685864f15dc> in <module>()
#       1 a = 1
#       2 b = 2
# ----> 3 assert(a == None and b != None)
#
# AssertionError:
